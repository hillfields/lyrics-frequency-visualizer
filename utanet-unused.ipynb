# %% [markdown]
# # Importing Modules

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import os

# %% [markdown]
# # UtaNet Class

# %% [markdown]
# This was my initial attempt at scraping lyrics. I ended up not using this class due to the following reasons:
#
# 1. The `search_utanet_lyrics()` method sometimes returns an `AttributeError` when extracting the song information on [Uta-Net](https://www.uta-net.com/). More specifically, the desired text chunk is not found, which returns `None`. Then finding another text chunk within the first chunk means calling `None.find()`, which most likely causes the error (see [Tests](#tests)). This method worked in an earlier version of this class, but the website underwent a change since I last updated the code.
#
# 2. The [Uta-Net](https://www.uta-net.com/) database has less songs (at least the ones I wanted) compared to the [Lyrical Nonsense](https://www.lyrical-nonsense.com/) database.
#
# 3. The query search is pretty strict because it must have the exact song title and artist to work properly. Unlike the `LyricsExtract` class, the `UtaNet` class does not make use of any search engines (which are more flexible with keywords).

# %%
class UtaNet:
    """Scrapes lyrics from Uta-Net (https://www.uta.net.com)."""
    def __init__(self):
        """Initializes the class."""
        pass

    def get_beautiful_soup_html(self, url, params=None):
        """Returns the HTML of a URL as a BeautifulSoup object."""
        # open the webpage of the URL and extract the HTML text
        with requests.Session() as session:
            response = session.get(url, params=params)
            html = response.text
        
        # return the HTML as a BeautifulSoup object
        soup = BeautifulSoup(html, "html.parser")
        return soup
    
    def get_utanet_lyrics(self, url):
        """Takes a Uta-Net URL to a song and returns the lyrics with line breaks intact."""
        # get the HTML text (a BeautifulSoup object) from the URL
        soup = self.get_beautiful_soup_html(url)

        # extract the section containing the lyrics
        lyrics = soup.find("div", class_="row pt-4 pe-2 ps-lg-3 pb-lg-4 kashi").find("div", itemprop="text")
        
        # clean the lyrics - keep line breaks & remove div tags
        lyrics = str(lyrics).replace("<br/>", "\n")
        lyrics = re.sub(r"</?div.*?>", "", lyrics)
        
        return lyrics

    def search_utanet_lyrics(self, artist, song):
        """Given an artist and one of their songs, returns the corrected artist name and lyrics with line breaks intact.
        If no such entry exists on Uta-Net, prints the available song entries for the given artist and returns False.
        """
        # parameters to search on Uta-Net
        params = {
            'Aselect': 1,
            'Keyword': artist,
            'Bselect': 3,
            'x': 0,
            'y': 0
        }
        
        # extract the results, which are contained in tables
        soup = self.get_beautiful_soup_html("https://www.uta-net.com/search/", params=params)
        tables = soup.find_all("tbody")

        # find the HTML section that contains the song name
        entries = []
        for table in tables:
            entries += table.find_all("tr")
        
        # find the match for the song
        song_no = None
        for entry in entries:
            if entry.find("td", class_="side td1").find("a", text=song):
                song_no = entry.find("td", class_="side td1").find("a")["href"]
                break
        
        # case 1: if the song was not found, print a list of available songs from the artist
        if not song_no:
            available_songs = [entry.find("td", class_="side td1").find("a").get_text() for entry in entries]
            print("The artist and song combination was not found on Uta-Net.")
            print("Available songs for {}:".format(artist))
            print(available_songs)
            print("-" * 20)
            return False
        
        # case 2: if the song was found, extract the lyrics and return it
        time.sleep(3)
        song_url = "https://www.uta-net.com" + song_no
        lyrics = self.get_utanet_lyrics(song_url)
        
        return lyrics
    
    def check_lyrics_file(self, artist, track, folder):
        """Checks if the lyrics file exists on the user's computer."""
        file_name = f"{artist}「{track}」.txt"
        path = os.path.join(folder, file_name)
        return os.path.isfile(path)
    
    def get_all_lyrics(self, artist, folder="artists", buffer_time=7):
        """For a given artist, outputs text files of the lyrics to every one of their songs.
        For ethical web-scraping, the default buffer time between each scrape is 7 seconds (like a human visitor).
        """
        # if the directory folder/artist doesn't exist, create a new directory
        artist_folder = f"{folder}/{artist}"
        if not os.path.isdir(artist_folder):
            os.makedirs(artist_folder)

        # parameters to search on Uta-Net
        params = {
            'Aselect': 1,
            'Keyword': artist,
            'Bselect': 4
        }
        
        # extract the results, which are contained in tables
        soup = self.get_beautiful_soup_html("https://www.uta-net.com/search/", params=params)
        tables = soup.find_all("tbody")

        # case 1: if there are no results, then return None
        if not tables:
            print("There were no entries found for this artist.")
            print("Make sure to write the exact artist name you're looking for.")
            return None

        # case 2: if there are results, then proceed

        # find the HTML section that contains the song name
        entries = []
        for table in tables:
            entries += table.find_all("tr")

        # extract the song number on Uta-Net, song title, and artist
        for entry in entries:
            song_no = entry.find("td", class_="side td1").find("a")["href"]
            song_title = entry.find("td", class_="side td1").find("a").get_text()
            song_artist = entry.find("td", class_="td2").find("a").get_text()

            # if the lyrics file doesn't exist in the given folder, create the file if possible
            if not self.check_lyrics_file(song_artist, song_title, artist_folder):
                time.sleep(buffer_time)
                song_url = "https://www.uta-net.com" + song_no
                lyrics = self.get_utanet_lyrics(song_url)

                file_name = f"{song_artist}「{song_title}」.txt"
                path = os.path.join(artist_folder, file_name)

                # case 1: create the lyrics file
                try:
                    with open(path, "w") as out_file:
                        out_file.write(lyrics)
                    print(f"* {song_artist}「{song_title}」: File created")
                
                # case 2: error in creating the lyrics file
                except FileNotFoundError:
                    print(f"! {song_artist}「{song_title}」: Error creating file")

            # case 3: if the lyrics file already exists, then no need to do anything
            else:
                print(f"{song_artist}「{song_title}」: File already exists")
        
        print("Finished.")

# %% [markdown]
# # Tests

# %%
utanet = UtaNet()
utanet.get_beautiful_soup_html("https://www.uta-net.com/song/317311/")
# Out:
# <!DOCTYPE html>
#
# <html lang="ja">
# <head>
# <meta charset="utf-8"/>
# <title>Official髭男dism ミックスナッツ 歌詞 - 歌ネット</title>
# <link as="style" href="https://ures.jp/uta-net.com/css/3rd/bootstrap/bootstrap.css" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="「ミックスナッツ/Official髭男dism」の歌詞 って「イイネ！」" property="og:title"/>
# <meta content="「袋に詰められたナッツのような世間では 誰…」勇気をもらったり、泣けたり、癒されたり…、この歌詞をチェックしてみて！人の心を打つ「言葉」がぎっしり！" property="og:description"/>
# <meta content="https://www.uta-net.com/song/317311/" property="mixi:device-smartphone"/>
# <meta content="notitle, nodescription" name="mixi-check-robots"/>
# <meta content="https://www.uta-net.com/reverse/mixi_check/uta_net_logo_m.gif" property="og:image"/>
# <meta content="Official髭男dismの「ミックスナッツ」歌詞ページです。作詞:藤原聡,作曲:藤原聡。SPY×FAMILY オープニング (歌いだし)袋に詰められたナッツのような 歌ネットは無料の歌詞検索サービスです。" name="description">
# <meta content="歌詞,ミックスナッツ,Official髭男dism" name="keywords"/>
# <!-- ========== 20200602 FLUX banner ========== -->
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#
#             // Slotの場合分け
#             var hbSlots = [];
#             var Slots = [];
#
#             googletag.cmd.push(function () {
#                 var slotC;
#                 var slotD;
#                 var slotE;
#
#                 slotC = googletag.defineSlot('/9168657/PC_歌詞_第1レクタングル_300x250', [[300, 600], [300, 250]], 'div-gpt-ad-1506843085645-1').addService(googletag.pubads());
#                 slotD = googletag.defineSlot('/9168657/PC_歌詞_第2レクタングル_300x250', [[300, 600], [300, 250]], 'div-gpt-ad-1506843085645-2').addService(googletag.pubads());
#                 slotE = googletag.defineSlot('/9168657/PC_歌詞_第3レクタングル_300x250or300x600', [[300, 250], [300, 600]], 'div-gpt-ad-1626226026574-0').addService(googletag.pubads());
#
#                 // Prebid.jsの対象枠設定
#                 hbSlots.push(slotC);
#                 hbSlots.push(slotD);
#                 hbSlots.push(slotE);
#
#                 googletag.pubads().enableSingleRequest();
#                 googletag.pubads().disableInitialLoad();
#                 googletag.pubads().collapseEmptyDivs();
#                 googletag.enableServices();
#
#                 // HeaderBiddingの対象枠外枠は即座にrefresh
#                 googletag.pubads().refresh(Slots);
#
#                 googletag.pubads().addEventListener('slotRenderEnded', function (event) {
#                     var slot = event.slot;
#                     console.group('Slot', slot.getSlotElementId(), '[/9168657/PC_歌詞_第2レクタングル_300x250]:描画完了');
#
#                     // Log details of the rendered ad.
#                     console.log('Advertiser ID:', event.advertiserId);
#                     console.log('Campaign ID: ', event.campaignId);
#                     console.log('Creative ID: ', event.creativeId);
#                     console.log('Is empty?:', event.isEmpty);
#                     console.log('Line Item ID:', event.lineItemId);
#                     console.log('Size:', event.size);
#                     console.log('Source Agnostic Creative ID:', event.sourceAgnosticCreativeId);
#                     console.log('Source Agnostic Line Item ID:', event.sourceAgnosticLineItemId);
#
#                     let gumgumArray = [2773704394];
#                     if (gumgumArray.indexOf(event.campaignId) >= 0)
#                     {
#                         const element = document.getElementById('pcad2');
#                         //element.remove();
#                         console.log("%c削除対象です。", "font-weight: bold; color: red;");
#                     } else {
#                         console.log("%c削除対象外です。", "font-weight: bold; color: green;");
#                     }
#
#                     console.groupEnd();
#                 });
#             });
#         </script>
# <!-- Define callback function -->
# <script type="text/javascript">
#             var readyBids = {
#                 prebid: false,
#                 amazon: false,
#                 google: false
#             };
#             var failSafeTimeout = 3e3;
#
#             // when both APS and Prebid have returned, initiate ad request
#
#             var launchAdServer = function () {
#                 if (!readyBids.amazon || !readyBids.prebid) {
#                     return;
#                 }
#                 requestAdServer();
#             };
#
#             // sends adserver request
#             var requestAdServer = function () {
#                 if (!readyBids.google) {
#                     readyBids.google = true;
#                     googletag.cmd.push(function () {
#                         pbjs.que.push(function () {
#                             pbjs.setTargetingForGPTAsync();
#                         });
#                         apstag.setDisplayBids();
#                         googletag.pubads().refresh(hbSlots);
#                     });
#                 }
#             };
#         </script>
# <!-- /Define callback function -->
# <!-- FLUX head -->
# <script src="https://flux-cdn.com/client/pageone/flux_uta-net_TM.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#             var pbjs = pbjs || {};
#             pbjs.que = pbjs.que || [];
#         </script>
# <!-- /FLUX head -->
# <!-- APS head -->
# <script type="text/javascript">
#             var amazonBidder = function () {
#                 !function (a9, a, p, s, t, A, g) {
#                     if (a[a9])
#                         return;
#
#                     function q(c, r) {
#                         a[a9]._Q.push([c, r])
#                     }
#
#                     a[a9] = {
#                         init: function () {
#                             q("i", arguments);
#                         },
#                         fetchBids: function () {
#                             q("f", arguments);
#                         },
#                         setDisplayBids: function () {},
#                         targetingKeys: function () {
#                             return [];
#                         },
#                         _Q: []
#                     };
#
#                     A = p.createElement(s);
#                     A.async = !0;
#                     A.src = t;
#                     g = p.getElementsByTagName(s)[0];
#                     g.parentNode.insertBefore(A, g);
#                 }("apstag", window, document, "script", "//c.amazon-adsystem.com/aax2/apstag.js");
#
#                 apstag.init({
#                     pubID: '3663', //発行されたpubID
#                     adServer: 'googletag',
#                     bidTimeout: 1e3
#                 });
#
#                 apstag.fetchBids({
#                     slots: [
#                         {
#                             slotID: 'div-gpt-ad-1506843085645-1',
#                             slotName: '9168657/PC_kashi_rec1',
#                             sizes: [[300, 600], [300, 250]]
#                         },
#                         {
#                             slotID: 'div-gpt-ad-1506843085645-2',
#                             slotName: '9168657/PC_kashi_rec2',
#                             sizes: [[300, 600], [300, 250]]
#                         },
#                         {
#                             slotID: 'div-gpt-ad-1626226026574-0',
#                             slotName: '9168657/PC_kashi_rec3',
#                             sizes: [[300, 250], [300, 600]]
#                         },
#                     ]
#                 }, function (bids) {
#                     googletag.cmd.push(function () {
#                         readyBids.amazon = true;	// 追加記述
#                         launchAdServer();			// 追加記述
#                     });
#                 });
#             } // amazon function
#         </script>
# <!-- /APS head -->
# <script>
#             var headerBiddingCall = function () { // {}の中に記述を追加します
#                 prebidBidder(); // 追加した行
#                 amazonBidder(); // 追加した行
#             }
#             // initiate bid request
#             headerBiddingCall();
#             // set failsafe timeout
#             setTimeout(function () {
#                 requestAdServer();
#             }, failSafeTimeout);
#         </script>
# <link href="https://ures.jp/uta-net.com/css/3rd/bootstrap/bootstrap.css" rel="stylesheet"/>
# <style>﻿#pc-header,#sp-header{font-family:'ヒラギノ角ゴ ProN W3','Hiragino Kaku Gothic ProN W3','メイリオ',Meiryo,sans-serif}body{background-color:#F5F5F5;font-family:Arial, system-ui;-webkit-font-smoothing:subpixel-antialiased;-moz-osx-font-smoothing:grayscale}@media (orientation: portrait) and (max-width: 992px){body{padding-top:44px}}@media print{body.moviesong{display:none}}#overlay_banner .overlay_inner{width:100%;text-align:center;position:fixed;bottom:0px;z-index:100}.rankinglog-header{text-align:center;width:100%;margin:0px 0px;padding:5px 0px;background-color:#CC0000;font-weight:bold;font-size:14px;color:#FFFFFF}#sp-header{font-family:'ヒラギノ角ゴ ProN W3','Hiragino Kaku Gothic ProN W3','メイリオ',Meiryo,sans-serif !important;background-color:#FFF;min-height:44px}@media (orientation: portrait) and (max-width: 992px){#sp-header{position:fixed;z-index:999;top:0px;left:0px}}#sp-header #header-search{position:relative;z-index:9;background:#FFF;padding:0px}#sp-header #header-search form{margin:10px}#sp-header #header-search ul{list-style:none;padding:0px;margin:0px 0px 5px 0px}#sp-header #header-search ul li{display:inline-block;font-size:12px;padding:0px 8px;border-right:#E5E5E5 1px solid}#sp-header #header-search ul li:last-child{border-right:0px;padding-right:0px}#sp-header #header-search ul li:first-child{padding-left:0px}#sp-header #header-search ul li a{color:#000;text-decoration:none}#sp-header #header-search ul li a.active{color:#CC0000;font-weight:700}#sp-header #header-search input.searchkeyword{font-size:14px;line-height:44px;height:44px;border-color:#1D1D6A;border-width:2px}#sp-header #header-search button[type='submit']{background:#1D1D6A url("data:image/svg+xml;charset=utf8,%3Csvg%20xmlns%3D%22http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%22%20width%3D%2216%22%20height%3D%2216%22%20fill%3D%22%23FFF%22%20class%3D%22bi%20bi-search%22%20viewBox%3D%220%200%2016%2016%22%3E%20%3Cpath%20d%3D%22M11.742%2010.344a6.5%206.5%200%201%200-1.397%201.398h-.001c.03.04.062.078.098.115l3.85%203.85a1%201%200%200%200%201.415-1.414l-3.85-3.85a1.007%201.007%200%200%200-.115-.1zM12%206.5a5.5%205.5%200%201%201-11%200%205.5%205.5%200%200%201%2011%200z%22%2F%3E%3C%2Fsvg%3E") no-repeat 20px center;background-size:16px;padding:0px 20px 0px 40px;color:#FFF;border-color:#1D1D6A;border-width:2px;height:44px}#sp-header #header-search button[type='submit']:hover{opacity:0.8}#sp-header #header-menu p.title{background-color:#35528A;color:#FFF;text-align:center;width:100%;height:23px;line-height:23px;font-size:15px;font-weight:700}#sp-header #header-menu ul.menu-list{background-color:#FFF;overflow:hidden}#sp-header #header-menu ul.menu-list li{float:left;display:table;width:33%;height:64px;padding:3px 0px;text-align:center;border-bottom:1px solid #BCBCBC}#sp-header #header-menu ul.menu-list li a{display:table-cell;position:relative;vertical-align:middle;padding-bottom:15px;border-right:1px solid #BCBCBC}#sp-header #header-menu ul.menu-list li a img{display:block;margin:0px auto}#sp-header #header-menu ul.menu-list li a span{position:absolute;bottom:3px;left:0px;display:block;width:100%;font-size:10px;line-height:14px;text-align:center;color:#333}#sp-header #header-menu ul.menu-list li:nth-last-child(-n+3){border-bottom:0px}#sp-header #header-menu ul.menu-list li:nth-child(3n+2){width:34%}#sp-header #header-menu ul.menu-list li:nth-child(3n) a{border-right:0px}#sp-header #header-menu ul.menu-list li.disable span{color:#999}#sp-header #header-menu ul.menu-list.first{border-bottom:2px solid #3A4E8B}#sp-header #header-menu ul.menu-list.first li{border-bottom:0px}#sp-header #header-menu ul.sns_list{padding:10px 0px;text-align:center;border-top:1px solid #BCBCBC;border-bottom:2px solid #3A4E8B;background-color:#EEEEEE}#sp-header #header-menu ul.sns_list li{display:inline-block;width:70px;height:37px}#pc-header{font-family:'ヒラギノ角ゴ ProN W3','Hiragino Kaku Gothic ProN W3','メイリオ',Meiryo,sans-serif !important;width:100%;text-align:left;background-color:#FFFFFF;position:relative;z-ind ...
# /*# sourceMappingURL=default.css.map */
# #kashi-page .main{background-color:transparent;max-width:calc(100% - 350px)}@media screen and (max-width: 992px){#kashi-page .main{max-width:100%}}#kashi-page .song-infoboard{position:relative;min-height:200px;background-size:cover;background-color:#FFF;background-blend-mode:darken;backdrop-filter:blur(12px);-webkit-backdrop-filter:blur(12px);background-repeat:no-repeat;color:#ffffff}#kashi-page .song-infoboard h3{font-size:100%}#kashi-page .song-infoboard h3 a{text-decoration:none;color:#ffffff}#kashi-page .song-infoboard .detail{letter-spacing:.1rem;font-size:11px;line-height:1.6}#kashi-page .song-infoboard .detail a{color:#ffffff}#kashi-page .song-infoboard button{width:50px;height:50px}#kashi-page .song-infoboard .sp-jacket{min-height:120px}#kashi-page .song-infoboard::before{content:'';position:absolute;background:rgba(0,0,0,0.7);width:100%;height:100%;left:0px;top:0px}#kashi-page .blur-filter{height:100%;backdrop-filter:blur(5px);-webkit-backdrop-filter:blur(5px);position:relative}#kashi-page .pc-jacket{max-width:195px}#kashi-page .kashi-related{background-color:#E5E5E5}#kashi-page .kashi-related .playbtn-row .btn{padding-top:6px;padding-bottom:6px;background:#666666}#kashi-page .kashi-related .playbtn-row .btn:disabled{background:#999999;border-color:#999;color:#DDD;opacity:1}#kashi-page .kashi-related .links-row2 .btn{padding-top:7px;padding-bottom:7px;font-size:13px;font-weight:700;color:#393939}#kashi-page .kashi-related .links-row2 .btn.disabled{background-color:#f1f1f1;border-color:#f1f1f1;color:#858585;opacity:1}@media screen and (max-width: 768px) and (orientation: landscape){#kashi-page .kashi-related.floating{padding-top:67px !important}#kashi-page .kashi-related.floating .playbtn-row{background-color:#E5E5E5;position:fixed;top:0px;left:0px;padding-top:16px;padding-bottom:16px;z-index:2}}#kashi-page .side-article-box{border-top:#CC0000 solid 3px;padding-top:15px}#kashi-page .side-article-box .ttl{border-left:#CC0000 solid 7px;padding-left:10px;font-weight:700;font-size:16px;padding-bottom:2px;margin:0px;display:flex;justify-content:start;align-items:center}#kashi-page .side-article-box .ttl span{font-size:12px;padding-left:5px}@media screen and (max-width: 992px){#kashi-page .side-article-box .ttl{padding-bottom:4px;font-size:26px;font-weight:700;display:block;line-height:1.2}#kashi-page .side-article-box .ttl span{display:block;padding-left:0px;font-weight:700}}#kashi-page .side-article-box .list{counter-reset:item}#kashi-page .side-article-box .list li{list-style:none;border-bottom:1px solid #E5E5E5}#kashi-page .side-article-box .list li .thumb{display:block;position:relative;width:100px;height:68px}#kashi-page .side-article-box .list li .thumb img{object-fit:scale-down;position:absolute;top:0px;width:100%;height:100%}#kashi-page .side-article-box .list li .title{display:block;width:calc(100% - 100px);z-index:1;padding:5px;font-size:12px}#kashi-page .side-article-box .list li:last-child{border-bottom:0px}#kashi-page .side-article-box .list li a{color:#000;text-decoration:none;display:flex;padding:15px 0px}#kashi-page .kashi{padding:0px 15px;margin-left:-12px;color:#303030;border-bottom:20px solid #F5F5F5;background:#FFF}@media screen and (max-width: 992px){#kashi-page .kashi{border-bottom:0px;margin-left:-15px;font-size:14px}}#kashi-page .kotoba-post #kotoba-form p.title,#kashi-page .kotoba-post #kotoba-form-ab p.title{background-color:#FFDEDE;margin:12px 12px 0px 12px;padding:15px 0px 0px 0px;text-align:center}#kashi-page .kotoba-post #kotoba-form .read_text,#kashi-page .kotoba-post #kotoba-form-ab .read_text{background-color:#FFDEDE;margin:0px 12px 0px 12px;padding:15px 10px;font-size:14px;line-height:1.3}#kashi-page .kotoba-post #kotoba-form form,#kashi-page .kotoba-post #kotoba-form-ab form{margin:0px;padding:0px}#kashi-page .kotoba-post #kotoba-form form dl,#kashi-page .kotoba-post #kotoba-form-ab form dl{background-color:#FFDEDE;padding:0px 8px 15px 8px;margin:0px 12px 12px 12px;font-size:14px}#kashi-pa ...
# /*# sourceMappingURL=kashi.css.map */
# </style>
# <link href="https://www.uta-net.com/" rel="contents" title="歌詞検索"/>
# <link href="https://www.uta-net.com/song/317311/" rel="canonical">
# <link href="https://ures.jp/uta-net.com/img/favicon.ico" rel="shortcut icon"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KKM6Z39');</script>
# <!-- End Google Tag Manager -->
# <script type="application/ld+json">{"@context": "http://schema.org","@type": "WebPage","name":"Official髭男dism ミックスナッツ 歌詞 - 歌ネット","url":"https://www.uta-net.com/song/317311/","relatedLink":"https://www.uta-net.com/artist/18093/","description":"Official髭男dismの「ミックスナッツ」歌詞ページです。作詞:藤原聡,作曲:藤原聡。SPY×FAMILY オープニング(歌いだし)袋に詰められたナッツのような 歌ネットは無料の歌詞検索サービスです。","copyrightHolder":{"@type": "Organization","logo":"https://ures.jp/uta-net.com//img/mixi_check/uta_net_logo_m.gif"},"breadcrumb":{"@type": "BreadcrumbList","itemListElement": [{"@type": "ListItem","position": 1,"item": {"@id": "https://www.uta-net.com/","name": "歌ネット"}},{"@type": "ListItem","position": 2,"item": {"@id": "https://www.uta-net.com/artist/18093/","name": "Official髭男dismの歌詞一覧"}}]}}</script>
# </link></meta></head>
# <body class="moviesong">
# <script src="//d-cache.microad.jp/js/td_un_access.js" type="text/javascript"></script>
# <script type="text/javascript">
#   microadTd.UN.start({"song_id": "317311" , "song_name": "ミックスナッツ" ,
# "artist_id": "18093" , "artist_name": "Official髭男dism" ,
# "lyricist_id": "" , "lyricist_name": "藤原聡" ,
# "composer_id": "37991" , "composer_name": "藤原聡"});
# </script>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KKM6Z39" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="container-fulid">
# <div class="row m-0">
# <div class="col-12 d-none d-lg-block p-0" id="pc-header">
# <div class="row align-items-center" id="header-main">
# <div class="logo col"><h1><a href="/"><img alt="ミックスナッツ Official髭男dism 歌詞｜歌詞検索サービス「歌ネット」" height="40" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/logo.png?0" width="194"/></a></h1></div>
# <div class="header-searchbox col">
# <form action="/search/" class="searchbox" method="get">
# <ul class="text-start searchbox-select"><li><a class="active" href="?target=art">アーティスト</a></li><li><a href="?Aselect=2">曲名</a></li><li><a href="?target=lyricist">作詞者</a></li><li><a href="?target=composer">作曲者</a></li><li><a href="?target=kashi">歌詞</a></li><li><a href="?target=tieup">タイアップ</a></li></ul>
# <input class="input-hidden" name="target" type="hidden" value="art"/>
# <input class="input-hidden" name="type" type="hidden" value="in"/>
# <div class="input-group mb-3">
# <input aria-describedby="basic-addon2" aria-label="アーティスト名で歌詞検索" class="form-control searchkeyword" name="Keyword" placeholder="アーティスト名で歌詞検索" type="text"/>
# <button class="btn btn-outline-secondary" id="button-addon2" onclick="dataLayer.push({
#                                            event: 'pc_analytics',
# 											eventCategory: 'header-search-song', eventAction: 'click',});" type="submit">検索</button>
# </div>
# </form>
# </div>
# <div class="header-myutanet col pe-0"><a class="header-myutanet-regist" href="/account/register.php" onclick="dataLayer.push({event: 'pc_analytics',eventCategory: 'header-regist', eventAction: 'click',});">ユーザー登録</a><a class="header-myutanet-login" href="/account/signin.php" onclick="dataLayer.push({event: 'pc_analytics',eventCategory: 'header-login', eventAction: 'click',});">ログイン</a></div>
# </div>
# <div id="nav-area"><ul class="nav row" id="nav-one"><li class="col ms-3" id="menu_top"><a href="/">ホーム</a></li><li class="col dropdown dropdown-hover" id="menu_search"><a class="dropdown-toggle" data-bs-offset="0,0" data-bs-toggle="dropdown" href="/name_list/" id="dropdownMenu1">歌詞検索</a><ul aria-labelledby="dropdownMenu1" class="dropdown-menu"><li><a href="/name_list/">アーティスト名インデックス検索</a></li><li><a href="/lyricist_list/">作詞者名インデックス検索</a></li><li><a href="/composer_list/">作曲者名インデックス検索</a></li><li><a href="/arranger_list/">編曲者名インデックス検索</a></li><li><a href="/record_label_list/">レーベル名インデックス検索</a></li><li><a href="/search/all/">歌詞全文（フレーズ）検索</a></li><li><a href="/anime_list/">アニソン検索</a></li><li><a href="/user/search_index/name.html">アルバム検索</a></li><li><a href="/user/timemachine/index.html">タイムマシン検索</a></li></ul></li><li class="col dropdown dropdown-hover" id="menu_newsong"><a class="dropdown-toggle" data-bs-offset="0,0" data-bs-toggle="dropdown" href="/song_info/" id="dropdownMenu2">新曲歌詞情報</a><ul aria-labelledby="dropdownMenu2" class="dropdown-menu"><li><a href="/song_info/">新曲歌詞情報（総合）</a></li><li><a href="/user/newsong/release_top_2.html">新曲歌詞情報（演歌・歌謡曲）</a></li><li><a href="/contact/">リクエストフォーム</a></li></ul></li><li class="col dropdown dropdown-hover" id="menu_ranking"><a class="dropdown-toggle" data-bs-offset="0,0" data-bs-toggle="dropdown" href="/ranking/daily/" id="dropdownMenu3">ランキング</a><ul aria-labelledby="dropdownMenu3" class="dropdown-menu"><li><a href="/ranking/daily/">総合ランキング</a></li><li><a href="/ranking/enka_kayo_weekly/">演歌・歌謡曲ランキング</a></li><li><a href="/ranking/total/">歴代人気曲ランキング</a></li><li><a href="/ranking/attention/">注目度ランキング</a></li><li><a href="/ranking/favorite_weekly/">お気に入りアーティストランキング</a></li><li><a href="/ranking/karaoke_sogo/">カラオケランキング</a></li></ul></li><li class="col dropdown dropdown-hover" id="menu_watafure"><a class="dropdown-toggle" data-bs-offset="0,0" data-bs-toggle="dropdown" href="/watafure/ichiran/" id="dropdownMenu4">コトバのキモチ</a><ul aria-labelledby="dropdownMenu4" class="dropdown-menu"><li><a href="/watafure/new/">新規投稿フレーズ</a></li><li><a href="/watafure/ichiran/">コトバのキモチ</a></li><li><a href="/watafure/ichiran/#search_box">コトバのキモチ検索</a></li><li><a href="/user/watafure/watafure_ranking.php">コトバのキモチBEST10</a></li><li><a href="/watafure/form/">歌詞フレーズ投稿</a></li></ul></li><li class="col dropdown dropdown-hover" id="menu_timemachine"><a class="dropdown-toggle" data-bs-offset="0,0" data-bs-toggle="dropdown" href="/user/timemachine/index.html" id="dropdownMenu5">タイムマシン</a><ul aria-labelledby="dropdownMenu5" class="dropdown-menu"><li><a href="/user/timemachine/index.html">タイムマシンTOP</a></li><li><a href="/user/timemachine/best10/index.html">今月のスポットライト </a></li><li><a href="/user/jake_uta/jake_uta_top.html">歌謡界50年史1960-2000年代</a></li><li><a href="/user/tvdorama_song/1960.html">年代別テレビドラマ主題歌</a></li><li><a href="/user/record_taisyo/index.html">年代別日本レコード大賞</a></li><li><a href="/user/anime60_90/anime60_90.html">年代別アニメソング特集</a></li><li><a href="/user/kashiken/kashiken.html">年代別歌詞検定</a></li></ul></li><li class="col dropdown dropdown-hover" id="menu_otona"><a class="dropdown-toggle" data-bs-offset="0,0" data-bs-toggle="dropdown" href="/tv_program/music/" id="dropdownMenu6">音楽番組情報</a><ul aria-labelledby="dropdownMenu6" class="dropdown-menu"><li><a href="/tv_program/music/">音楽番組情報TOP</a></li><li><a href="/user/search_index/index.html">TVドラマ主題歌</a></li><li><a href="/user/search_index/anime.html">TVアニメソング</a></li><li><a href="/user/otona/m_station/m_station_songlist.html">MUSIC STATION放送曲目リスト</a></li><li><a href="/user/otona/nipon/nipon_songlist.html">新・BS日本のうた放送曲目リスト</a></li></ul></li><li class="col me-3" id="menu_movie"><a href="/movie/">動画プラス</a></li></ul></div>
# <div id="nav-area2"><ul class="row"><li class="col"><a href="/today/">今日のうた</a></li><li class="col"><a href="/livereport/">ライブレポート</a></li><li class="col"><a href="/streaming/">ストリーミング</a></li><li class="col"><a href="/user/interview/index.html">インタビュー</a></li><li class="col"><a href="/anime/index.html">アニメ</a></li><li class="col"><a href="/user/close_up/index.html">特集ピックアップ</a></li><li class="col"><a href="/user/column/index.html">言葉の魔法</a></li><li class="col"><a href="/user/tatsujin/index.html">言葉の達人</a></li></ul></div>
# </div>
# <div class="col-12 d-block d-lg-none p-0" id="sp-header">
# <div class="row justify-content-center m-0" style="border-bottom:1px solid #FFF;">
# <div class="col-auto my-2 mx-1">
# <a href="/"><img alt="歌詞検索サービス「歌ネット」" decoding="async" height="17" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/logo.png?0" width="81"/></a>
# </div>
# <h1 class="col text-truncate m-0" style="font-size: 13px;font-weight: bold;color: #7C7C7C;line-height:44px;padding:0px 10px 0px 0px;">Official髭男dism ミックスナッツ 歌詞</h1>
# <div class="col-auto accordion p-0 m-0">
# <div class="text-center" id="headerSearch">
# <a aria-controls="header-search" aria-expanded="true" data-bs-target="#header-search" data-bs-toggle="collapse" onclick="dataLayer.push({
#                                            event: 'pc_analytics',
# 											eventCategory: 'header-search-icon-song',
# 											eventAction: 'click',});" style="display:block;width:44px;height:44px;">
# <img alt="検索ボックスを開く" decoding="async" height="22" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/header_icon_search.png" style="margin-top:12px;" width="21"/>
# </a>
# </div>
# </div>
# <div class="col-auto accordion p-0 m-0">
# <div class="text-center" id="headerMenu">
# <a aria-controls="header-menu" aria-expanded="true" data-bs-target="#header-menu" data-bs-toggle="collapse" style="display:block;width:44px;height:44px;">
# <img alt="メニューを開く" decoding="async" height="19" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/header_icon_menu.png" style="margin-top:12px;" width="27"/>
# </a>
# </div>
# </div>
# </div>
# <div aria-labelledby="headerSeachbox" class="col-12 collapse" id="header-search"><form action="/search/" class="searchbox" method="get"><ul class="text-start searchbox-select"><li><a class="active" href="?target=art">アーティスト</a></li><li><a href="?Aselect=2">曲名</a></li><li><a href="?target=lyricist">作詞者</a></li><li><a href="?target=composer">作曲者</a></li><li><a href="?target=kashi">歌詞</a></li><li><a href="?target=tieup">タイアップ</a></li> </ul>
# <input class="input-hidden" name="target" type="hidden" value="art"/>
# <input class="input-hidden" name="type" type="hidden" value="in"/>
# <div class="input-group mb-3">
# <input aria-describedby="basic-addon2" aria-label="アーティスト名で歌詞検索" class="form-control searchkeyword" name="keyword" placeholder="アーティスト名で歌詞検索" type="text"/>
# <button class="btn btn-outline-secondary" id="button-addon2" onclick="dataLayer.push({
#                                            event: 'pc_analytics',
# 											eventCategory: 'header-search-song',
# 											eventAction: 'click',});" type="submit">検索</button>
# </div>
# </form>
# </div>
# <div aria-labelledby="headerMenu" class="col-12 collapse" id="header-menu"><p class="title p-0 m-0">MENU</p><ul class="menu-list first p-0 m-0"><li><a href="/"><img alt="ホーム" decoding="async" height="30" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_home.png" width="34"/><span>ホーム</span></a></li><li><a href="/movie/daily_ranking/"><img alt="動画プラス" decoding="async" height="32" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_dougaplus.png" width="48"/><span>動画プラス</span></a></li><li><a href="/myuta/"><img alt="マイ歌ネット" decoding="async" height="34" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_myuta_off.png" width="34"/><span>マイ歌ネット</span></a></li></ul><ul class="menu-list p-0 m-0"><li><a href="/search/history.php"><img alt="歌詞閲覧履歴" decoding="async" height="31" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_history.png" width="34"/><span>歌詞閲覧履歴</span></a></li><li><a href="/ranking/daily/"><img alt="ランキング" decoding="async" height="28" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_ranking.png" width="35"/><span>ランキング</span></a></li><li><a href="/song_info/"><img alt="新曲歌詞情報" decoding="async" height="35" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_newsong.png" width="35"/><span>新曲歌詞情報</span></a></li><li><a href="/today/"><img alt="今日のうた" decoding="async" height="35" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_today.png" width="35"/><span>今日のうた</span></a></li><li><a href="/news/"><img alt="ニュース" decoding="async" height="35" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_news.png" width="35"/><span>ニュース</span></a></li><li><a href="/livereport/"><img alt="ライブレポート" decoding="async" height="34" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_live.png" width="35"/><span>ライブレポート</span></a></li><li><a href="/watafure/ichiran/"><img alt="コトバのキモチ" decoding="async" height="30" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_kimochi.png" width="35"/><span>コトバのキモチ</span></a></li><li><a href="/user/tatsujin/index.html"><img alt="言葉の達人" decoding="async" height="35" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_tatsujin.png" width="35"/><span>言葉の達人</span></a></li><li><a href="/user/column/index.html"><img alt="言葉の魔法" decoding="async" height="32" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_column.png" width="28"/><span>言葉の魔法</span></a></li><li><a href="/user/pickup/index.html"><img alt="歌ネットピックアップ" decoding="async" height="35" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_pickup.png" width="35"/><span>ピックアップ</span></a></li><li><a href="/tv_program/music/"><img alt="音楽番組情報" decoding="async" height="28" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_bangumi.png" width="33"/><span>音楽番組情報</span></a></li><li><a href="/contact/"><img alt="リクエスト" decoding="async" height="24" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_request.png" width="35"/><span>リクエスト</span></a></li><li><a href="/streaming/"><img alt="ストリーミング" decoding="async" height="35" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_streaming.png" width="35"/><span>ストリーミング</span></a></li><li><a href="/anime/"><img alt="アニメ" decoding="async" height="35" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/menu_icon_anime.png" width="35"/><span>アニメ</span></a></li><li> </li></ul><ul class="sns_list p-2 m-0"><li><a href="https://twitter.com/share?url=https%3A%2F%2Fwww.uta-net.com%2Fsong%2F317311%2F&amp;text=Official%E9%AB%AD%E7%94%B7dism%E3%80%8C%E3%83%9F%E3%83%83%E3%82%AF%E3%82%B9%E3%83%8A%E3%83%83%E3%83%84%E3%80%8D%E3%81%AE%E6%AD%8C%E8%A9%9E%20%2F%20%E6%AD%8C%E8%A9%9E%E6%A4%9C%E7%B4%A2%E3%82%B5%E3%83%BC%E3%83%93%E3%82%B9%E3%80%8C%E6%AD%8C%E3%83%8D%E3%83%83%E3%83%88%E3%80%8D&amp;hashtags=utanet" target="_blank"><img alt="twitter" decoding="async" height="37" loading="lazy" src="https://ures.jp/uta-net.com/im ...
# </div>
# </div>
# </div>
# <div class="container-xl">
# <div class="row justify-content-left mt-lg-5" id="kashi-page">
# <div class="main col-sm-12 col-lg-8 flex-grow-1 ms-lg-3" id="left-contents">
# <!-- 楽曲情報ヘッダ -->
# <div class="row">
# <div class="col-12 song-infoboard" itemscope="" itemtype="http://schema.org/MusicComposition" style="min-height: 226px; background-image: url('https://www.uta-net.com/libs/cacheimg.php?p=kashi&amp;f=320000/317311.jpg');">
# <div class="blur-filter row py-3">
# <div class="col-12 col-md">
# <div class="row h-100">
# <div class="col-8 col-md-12 my-2">
# <h2 class="ms-2 ms-md-3">ミックスナッツ</h2>
# <h3 class="ms-2 ms-md-3" itemprop="recordedAs" itemscope="" itemtype="http://schema.org/MusicRecording">
# <a href="/artist/18093/" itemprop="byArtist"><span itemprop="byArtist name">Official髭男dism</span></a></h3>
# </div>
# <div class="sp-jacket d-block d-md-none col-4 mt-2 p-0"><img alt="ミックスナッツ" decoding="async" height="100" src="https://www.uta-net.com/libs/cacheimg.php?p=kashi&amp;f=320000/317311.jpg" style="width: 100px; height: auto;" width="100"/></div>
# <div class="col-8 align-self-end">
# <p class="ms-2 ms-md-3 mb-0" style="font-size:12px;">
#                                             SPY×FAMILY オープニング
#                                         </p> <p class="ms-2 ms-md-3 detail mb-0">
#                                             作詞：<a href="/lyricist/37609/" itemprop="lyricist">藤原聡</a><br/>
#                                             作曲：<a href="/composer/37991/" itemprop="composer">藤原聡</a><br/>
#                                                                                         発売日：2022/04/15<br/>                                            この曲の表示回数：865,644回
#                                         </p>
# </div>
# <div class="col-4 m-0 align-self-top align-self-md-end">
# <div class="row mt-1 justify-content-end">
# <div class="col-6 p-0">
# <a href="/ranking/total/"><img alt="歴代！" class="d-block d-sm-none" decoding="async" height="40" src="https://ures.jp/uta-net.com/img/sp/platina.png" width="40"/></a>
# <a href="/ranking/total/"><img alt="歴代！" class="d-none d-sm-block float-end" decoding="async" height="30" src="https://ures.jp/uta-net.com/img/pc/platina.png" width="90"/></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-3 pc-jacket ps-2 d-none d-md-block"><img alt="ミックスナッツ" class="float-end img-fluid" decoding="async" height="180" src="https://www.uta-net.com/libs/cacheimg.php?p=kashi&amp;f=320000/317311.jpg" width="180"/></div>
# </div>
# </div>
# </div>
# <!-- /楽曲情報ヘッダ -->
# <!-- 楽曲操作ボタン -->
# <div class="row kashi-related pt-3 pb-3">
# <div class="col-sm-12 col-md-5 pb-3 pb-md-0 playbtn-row">
# <div class="row">
# <div class="col-6 ps-3 pe-2" id="songFloatLeftButton">
# <button class="btn btn-sm btn-secondary w-100 soundplay" data-id="soundplay">
# <img alt="試聴をする" class="align-text-top" height="19" src="https://ures.jp/uta-net.com/img/icon_itunes.png" width="19"/> 試聴をする
#                                                     </button>
# <audio controlslist="nodownload" id="soundplay" preload="metadata" src="https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview112/v4/41/c6/8d/41c68dfb-f604-3a78-1803-e5fd3c873209/mzaf_11350318999317077588.plus.aac.p.m4a"></audio>
# </div>
# <div class="col-6 pe-3 pe-md-2 ps-2" id="songFloatRightButton">
# <a class="btn btn-sm btn-secondary w-100" href="/movie/317311/" id="toMovieButton" itemprop="url" onclick="dataLayer.push({
# 															   event: 'pc_analytics', eventCategory: 'song-movie',
# 																	   eventAction: 'click', eventLabel: 'TID', eventValue: 317311 });">
# <img alt="動画を見る" class="align-text-top" height="19" src="https://ures.jp/uta-net.com/img/icon_movie.png" width="19"/> <span id="toMovieButtonText">動画を見る</span></a></div></div></div></div></div></div></div></body></html>
#
#
#
# <div class="col-sm-12 col-md-7 links-row2">
# <div class="row">
# <div class="col-3 ps-3 ps-md-2 pe-1 pe-sm-2">
# <a class="btn btn-sm btn-light w-100 px-0" href="/artist/18093/" onclick="dataLayer.push({
# 													   event: 'pc_analytics', eventCategory: 'song-artist',
# 															   eventAction: 'click', eventLabel: 'AID', eventValue: 18093 });">歌詞一覧</a>
# </div>
# <div class="col-3 px-1 px-sm-2">
# <a class="btn btn-sm btn-light w-100 px-0" href="/user/search_index/artist.html?AID=18093" onclick="dataLayer.push({
# 														   event: 'pc_analytics', eventCategory: 'song-album', eventAction: 'click',
# 																   eventLabel: 'AID', eventValue: 18093 });">アルバム一覧</a>
# </div>
# <div class="col-3 px-1 px-sm-2">
# <button class="btn btn-sm btn-light w-100 px-0" data-bs-target="#buyModal" data-bs-toggle="modal">購入</button>
# </div>
# <div class="col-3 pe-3 pe-md-3 ps-1 ps-sm-2">
# <button class="btn btn-sm btn-light w-100 px-0" data-bs-target="#shareModal" data-bs-toggle="modal">シェア</button>
# </div>
# </div>
# </div>
#
# <!-- /楽曲操作ボタン -->
# <!-- 歌詞表示エリア -->
# <div class="row pt-4 pe-2 ps-lg-3 pb-lg-4 kashi" id="kashi-box">
# <div class="col-12 px-0 px-lg-3" itemprop="lyrics" itemscope="" itemtype="http://schema.org/CreativeWork">
# <div id="kashi_area" itemprop="text">袋に詰められたナッツのような世間では<br/>誰もがそれぞれ出会った誰かと寄り添い合ってる<br/>そこに紛れ込んだ僕らはピーナッツみたいに<br/>木の実のフリしながら　微笑み浮かべる<br/><br/>幸せのテンプレートの上　文字通り絵に描いたうわべの裏<br/>テーブルを囲み手を合わすその時さえ　ありのままでは居られないまま<br/><br/>隠し事だらけ　継ぎ接ぎだらけのHome, you know？<br/>噛み砕いても無くならない　本音が歯に挟まったまま<br/>不安だらけ　成り行き任せのLife, and I know<br/>仮初めまみれの日常だけど　ここに僕が居て　あなたが居る<br/>この真実だけでもう　胃がもたれてゆく<br/><br/>化けの皮剥がれた一粒のピーナッツみたいに<br/>世間から一瞬で弾かれてしまう　そんな時こそ<br/>曲がりなりで良かったらそばに居させて<br/>共に煎られ　揺られ　踏まれても　割れない殻みたいになるから<br/><br/>生まれた場所が木の上か地面の中か　それだけの違い<br/>許されないほどにドライなこの世界を　等しく雨が湿らせますように<br/><br/>時に冷たくて　騒がしい窓の向こうyou know？<br/>星の一つも見つからない　雷に満ちた日があっても良い<br/>ミスだらけ　アドリブ任せのShow, but I know<br/>所詮ひとかけの日常だから　腹の中にでも　流して寝よう<br/><br/>隠し事だらけ　継ぎ接ぎだらけのHome, you know？<br/>とっておきも出来合いも　残さずに全部食らいながら<br/>普通などない　正解などないLife, and I know<br/>仮初めまみれの日常だけど　ここに僕が居て　あなたが居る<br/>この真実だけでもう　胃がもたれてゆく<br/>この一掴みの奇跡を　噛み締めてゆく</div>
# <div class="d-none d-md-block text-end">
# <a href="/renew/myutanet/song_book.php?mode=add&amp;ID=317311" style="text-decoration: none;">この歌詞をマイ歌ネットに登録 &gt;</a><br/>
# <a href="/renew/myutanet/artist.php?mode=add&amp;aID=18093&amp;ID=317311" style="text-decoration: none;">このアーティストをマイ歌ネットに登録 &gt;</a><br/>
# </div>
# </div>
# </div>
# <!-- /歌詞表示エリア -->
# <!-- コトバのキモチ投稿フォーム -->
# <div class="row d-md-none pt-3 pb-4 kotoba-post bg-white abMain" id="kotoba_form">
# <div class="col-12 accordion" id="accordionKimochiForm">
# <div class="text-center" id="headingOne">
# <button aria-controls="kotoba-form" aria-expanded="true" class="btn btn-outline-dark rounded-pill" data-bs-target="#kotoba-form" data-bs-toggle="collapse" style="width: 90%;line-height: 2; font-size: 90%;" type="button">
#                                                 この曲のフレーズを投稿する
#                                             </button>
# </div>
# <div aria-labelledby="headingOne" class="collapse" data-bs-parent="#accordionKimochiForm" id="kotoba-form">
# <p class="title"><img alt="コトバのキモチ 投稿フォーム" decoding="async" height="48" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/form_title.png" width="200"/></p>
# <p class="read_text">ココでは、アナタのお気に入りの歌詞のフレーズを募集しています。<br/>下記の投稿フォームに必要事項を記入の上、アナタの「熱い想い」を添えてドシドシ送って下さい。</p>
# <form action="/watafure/form/?act=conf" autocomplete="off" method="post">
# <dl>
# <dt>推薦者：アナタのお名前（ペンネーム可）</dt>
# <dd><input autocapitalize="off" name="name" type="text" value=""/></dd>
# <dt class="short">性別：</dt>
# <dd class="short">
# <label><input checked="" name="sex" type="radio" value="1"/> 女性</label>
#                                                         <label><input name="sex" type="radio" value="0"/> 男性</label>
# </dd>
# <dt class="short">年齢：</dt>
# <dd class="short"><input maxlenth="3" name="age" style="ime-mode: disabled;" type="number" value=""/> 歳</dd>
# <dt>投稿フレーズ：</dt>
# <dd><textarea name="Phrase"></textarea></dd>
# <dt>曲名：</dt>
# <dd><input autocapitalize="off" name="Title" type="text" value="ミックスナッツ"/></dd>
# <dt>歌手名：</dt>
# <dd><input autocapitalize="off" name="Artist" type="text" value="Official髭男dism"/></dd>
# <dt class="comment">コメント：</dt>
# <dd><textarea name="Com"></textarea></dd>
# <dt>歌ネットに一言あれば：</dt>
# <dd>
# <textarea name="Mess"></textarea>
# <p style="font-size:13px;line-height:1.3;padding-top: 15px;padding-left:1em;text-indent:-0.5em;">
#                                                             ※歌詞間違いのご指摘、歌ネットへのご要望、<br/>
#                                                             その他返信希望のお問い合わせなどは<br/>
#                                                             コチラからどうぞ。→ <a href="/contact/" style="display:inline;color:#0000FF;">問い合わせフォーム</a>
# </p>
# </dd>
# </dl>
# <p class="text-center">
# <input name="pid" type="hidden" value=""/>
# <input name="tid" type="hidden" value="317311"/>
# <input name="bk" type="hidden" value=""/>
# <input name="param" type="hidden" value=""/>
# <input class="submit" type="submit" value="プレビュー"/>
# </p>
# </form>
# </div>
# </div>
# </div>
# <!-- /コトバのキモチ投稿フォーム -->
# <!-- アーティスト人気曲 -->
# <div class="row artist-ranking pt-3 pb-4">
# <div class="col-12 pb-2">
# <h4 class="ms-2">
#                                             RANKING
#                                             <p class="mb-0">Official髭男dismの人気歌詞ランキング</p>
# </h4>
# </div>
# <ul class="row list bg_white m-0">
# <li class="ranktop arrow col-12 col-lg-3 pb-2 mb-2"><div class="jkimg"><a href="/song/317311/"><img alt="ミックスナッツ" class="rounded" decoding="async" height="100" loading="lazy" src="https://www.uta-net.com/libs/cacheimg.php?p=kashi&amp;f=320000/317311.jpg" width="100"/></a></div><div class="songdata p-2 pb-0 ps-lg-0 pe-lg-4"><a href="/song/317311/"><p class="title text-truncate">ミックスナッツ</p><p class="artist text-truncate">Official髭男dism</p></a></div></li>
# <li class="arrow col-12 col-lg-3 pb-2 mb-2"><div class="jkimg"><a href="/song/301712/"><img alt="Cry Baby" class="rounded" decoding="async" height="100" loading="lazy" src="https://www.uta-net.com/libs/cacheimg.php?p=kashi&amp;f=310000/301712.jpg" width="100"/></a></div><div class="songdata p-2 pb-0 ps-lg-0 pe-lg-4"><a href="/song/301712/"><p class="title text-truncate">Cry Baby</p><p class="artist text-truncate">Official髭男dism</p></a></div></li>
# <li class="arrow col-12 col-lg-3 pb-2 mb-2"><div class="jkimg"><a href="/song/266648/"><img alt="Pretender" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51-zxPTMCUL._SL240_.jpg" width="100"/></a></div><div class="songdata p-2 pb-0 ps-lg-0 pe-lg-4"><a href="/song/266648/"><p class="title text-truncate">Pretender</p><p class="artist text-truncate">Official髭男dism</p></a></div></li>
# <li class="arrow col-12 col-lg-3 pb-2 mb-2"><div class="jkimg"><a href="/song/280202/"><img alt="I LOVE..." class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/41IcXCMdXjL._SL240_.jpg" width="100"/></a></div><div class="songdata p-2 pb-0 ps-lg-0 pe-lg-4"><a href="/song/280202/"><p class="title text-truncate">I LOVE...</p><p class="artist text-truncate">Official髭男dism</p></a></div></li>
# <li class="arrow col-12 col-lg-2 pb-2 mb-2"><div class="jkimg"><a href="/song/247041/"><img alt="115万キロのフィルム" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/61-fm+HT7cL._SL240_.jpg" width="100"/></a></div><div class="songdata p-2 pb-0 ps-lg-0 pe-lg-4"><a href="/song/247041/"><p class="title text-truncate">115万キロのフィルム</p><p class="artist text-truncate">Official髭男dism</p></a></div></li>
# <li class="arrow col-2 pb-2 mb-2 d-none d-lg-block"><div class="jkimg"><a href="/song/274368/"><img alt="イエスタデイ" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51okqjnIM4L._SL240_.jpg" width="100"/></a></div><div class="songdata p-2 pb-0 ps-lg-0 pe-lg-4"><a href="/song/274368/"><p class="title text-truncate">イエスタデイ</p><p class="artist text-truncate">Official髭男dism</p></a></div></li>
# <li class="arrow col-2 pb-2 mb-2 d-none d-lg-block"><div class="jkimg"><a href="/song/270348/"><img alt="宿命" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51qDk8+Ta6L._SL240_.jpg" width="100"/></a></div><div class="songdata p-2 pb-0 ps-lg-0 pe-lg-4"><a href="/song/270348/"><p class="title text-truncate">宿命</p><p class="artist text-truncate">Official髭男dism</p></a></div></li>
# <li class="arrow col-2 pb-2 mb-2 d-none d-lg-block"><div class="jkimg"><a href="/song/247316/"><img alt="ノーダウト" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/61-fm+HT7cL._SL240_.jpg" width="100"/></a></div><div class="songdata p-2 pb-0 ps-lg-0 pe-lg-4"><a href="/song/247316/"><p class="title text-truncate">ノーダウト</p><p class="artist text-truncate">Official髭男dism</p></a></div></li>
# <li class="arrow col-2 pb-2 mb-2 d-none d-lg-block"><div class="jkimg"><a href="/song/287858/"><img alt="Laughter" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51DYiO3XjhL._SL240_.jpg" width="100"/></a></div><div class="songdata p-2 pb-0 ps-lg-0 pe-lg-4"><a href="/song/287858/"><p class="title text-truncate">Laughter</p><p class="artist text-truncate">Official髭男dism</p></a></div></li>
# <li class="arrow col-2 pb-2 mb-2 d-none d-lg-block"><div class="jkimg"><a href="/song/306126/"><img alt="アポトーシス" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/61G6+GE8bsS._SL240_.jpg" width="100"/></a></div><div class="songdata p-2 pb-0 ps-lg-0 pe-lg-4"><a href="/song/306126/"><p class="title text-truncate">アポトーシス</p><p class="artist text-truncate">Official髭男dism</p></a></div></li>
# <div aria-labelledby="rankingMore" class="collapse row p-0 ms-0" data-bs-parent="#accordionRanking" id="ranking-more"> <li class="arrow col-12 pb-2 mb-2 d-lg-none" style="background-position:right center;"><div class="jkimg"><img alt="イエスタデイ" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51okqjnIM4L._SL240_.jpg" width="100"/></div><div class="songdata p-2"><a href="/song/274368/"><p class="title text-truncate">イエスタデイ</p><p class="artist text-truncate">Official髭男dism</p></a></div></li> <li class="arrow col-12 pb-2 mb-2 d-lg-none"><div class="jkimg"><img alt="宿命" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51qDk8+Ta6L._SL240_.jpg" width="100"/></div><div class="songdata p-2"><a href="/song/270348/"><p class="title text-truncate">宿命</p><p class="artist text-truncate">Official髭男dism</p></a></div></li> <li class="arrow col-12 pb-2 mb-2 d-lg-none"><div class="jkimg"><img alt="ノーダウト" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/61-fm+HT7cL._SL240_.jpg" width="100"/></div><div class="songdata p-2"><a href="/song/247316/"><p class="title text-truncate">ノーダウト</p><p class="artist text-truncate">Official髭男dism</p></a></div></li> <li class="arrow col-12 pb-2 mb-2 d-lg-none"><div class="jkimg"><img alt="Laughter" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51DYiO3XjhL._SL240_.jpg" width="100"/></div><div class="songdata p-2"><a href="/song/287858/"><p class="title text-truncate">Laughter</p><p class="artist text-truncate">Official髭男dism</p></a></div></li> <li class="arrow col-12 pb-2 mb-2 d-lg-none"><div class="jkimg"><img alt="アポトーシス" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/61G6+GE8bsS._SL240_.jpg" width="100"/></div><div class="songdata p-2"><a href="/song/306126/"><p class="title text-truncate">アポトーシス</p><p class="artist text-truncate">Official髭男dism</p></a></div></li></div> </ul>
# <div class="accordion col-12 d-block d-lg-none" id="accordionRanking">
# <div class="text-center pt-2" id="rankingMore">
# <button aria-controls="ranking-more" aria-expanded="true" class="btn btn-outline-dark rounded-pill more-btn" data-bs-target="#ranking-more" data-bs-toggle="collapse" id="togglemsg-ranking" type="button">
# 																もっと見る
# 															</button>
# </div>
# </div>
# </div>
# <!-- /アーティスト人気曲 -->
# <div class="row kashi-newlist-history">
# <!-- 新着歌詞 -->
# <div class="row kashi-newlist rounded-3 mx-0 p-0">
# <div class="col-12 mb-0 pb-1 title">
# <h3><span>Official髭男dism</span>の新着歌詞</h3>
# <div class="artist-link d-none d-lg-block" style="min-width: 135px;">
# <a class="btn btn-outline-dark rounded-pill btn-sm" href="/artist/18093/">この歌手の歌詞一覧</a>
# </div>
# </div>
# <ul class="col-12 mb-0">
# <li><a href="/song/320524/" onclick="dataLayer.push({event: 'pc_analytics', eventCategory: 'song-new', eventAction: 'click', eventLabel: 'TID', eventValue: 320524});">
# 																	Choral A / ♪ つまんねぇと嘆いたら誰かが
# 																</a></li>
# <li><a href="/song/320523/" onclick="dataLayer.push({event: 'pc_analytics', eventCategory: 'song-new', eventAction: 'click', eventLabel: 'TID', eventValue: 320523});">
# 																	破顔 / ♪ 帰り道のライト何らかの合図を
# 																</a></li>
# ...
# </div>
# <div class="songdata pb-0 px-md-2 pe-md-5 text-truncate">
# <a href="/song/321128/">逆光</a><br/>
# <a href="/artist/29298/">Ado</a>
# </div>
# </li>
# <li class="col-12 pb-2 mb-0">
# <div class="jkimg">
# <a href="/song/322905/"><img alt="風のゆくえ" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/61+6IgTOsxL._SL240_.jpg" width="100"/></a>
# </div>
# <div class="songdata pb-0 px-md-2 pe-md-5 text-truncate">
# <a href="/song/322905/">風のゆくえ</a><br/>
# <a href="/artist/29298/">Ado</a>
# </div>
# </li>
# </ol>
# <div class="col-12 text-center more py-2">
# <a class="btn btn-outline-dark rounded-pill more-btn" href="/ranking/realtime/">もっと見る</a>
# </div>
# <p class="data_source pb-2">歌ネットのアクセス数を元に作成<br/>サムネイルはAmazonのデータを参照</p>
# </div>
# </div>
# <div class="row pc-right-column-block ms-lg-1 ms-x2 ad-area-b" id="pcad2">
# <div class="col-12 p-0">
# <!-- /9168657/PC_歌詞_第2レクタングル_300x250 -->
# <div id="div-gpt-ad-1506843085645-2" style="min-height:250px; width:300px;">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1506843085645-2'); });
# </script>
# </div>
# </div>
# </div>
# <div class="row pc-right-column-block ms-lg-1 ms-x2" style="margin-bottom:20px;">
# <div class="side-ranking-box" id="tyumoku_ranking">
# <p class="ttl">注目度ランキング</p>
# <ol class="list p-0 m-0 pb-2"> <li class="col-12 pb-2 mb-0">
# <div class="jkimg">
# <a href="/song/322947/"><img alt="BF is..." class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51YG6VlCToL._SL240_.jpg" width="100"/></a>
# </div>
# <div class="songdata pb-0 px-md-2 pe-md-5 text-truncate">
# <a href="/song/322947/">BF is...</a><br/>
# <a href="/artist/30961/">BE:FIRST</a>
# </div>
# </li>
# <li class="col-12 pb-2 mb-0">
# <div class="jkimg">
# <a href="/song/322051/"><img alt="Scream" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51YG6VlCToL._SL240_.jpg" width="100"/></a>
# </div>
# <div class="songdata pb-0 px-md-2 pe-md-5 text-truncate">
# <a href="/song/322051/">Scream</a><br/>
# <a href="/artist/30961/">BE:FIRST</a>
# </div>
# </li>
# <li class="col-12 pb-2 mb-0">
# <div class="jkimg">
# <a href="/song/322447/"><img alt="ベルベットの詩" class="rounded" decoding="async" height="100" loading="lazy" src="https://www.uta-net.com/libs/cacheimg.php?p=kashi&amp;f=330000/322447.jpg" width="100"/></a>
# </div>
# <div class="songdata pb-0 px-md-2 pe-md-5 text-truncate">
# <a href="/song/322447/">ベルベットの詩</a><br/>
# <a href="/artist/8613/">back number</a>
# </div>
# </li>
# <li class="col-12 pb-2 mb-0">
# <div class="jkimg">
# <a href="/song/322391/"><img alt="Beautiful" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51arDrqM8XL._SL240_.jpg" width="100"/></a>
# </div>
# <div class="songdata pb-0 px-md-2 pe-md-5 text-truncate">
# <a href="/song/322391/">Beautiful</a><br/>
# <a href="/artist/11237/">チャン・グンソク</a>
# </div>
# </li>
# <li class="col-12 pb-2 mb-0">
# <div class="jkimg">
# <a href="/song/322808/"><img alt="Be Free" class="rounded" decoding="async" height="100" loading="lazy" src="https://m.media-amazon.com/images/I/51YG6VlCToL._SL240_.jpg" width="100"/></a>
# </div>
# <div class="songdata pb-0 px-md-2 pe-md-5 text-truncate">
# <a href="/song/322808/">Be Free</a><br/>
# <a href="/artist/30961/">BE:FIRST</a>
# </div>
# </li>
# </ol>
# <div class="col-12 text-center more py-2">
# <a class="btn btn-outline-dark rounded-pill more-btn" href="/ranking/attention/">もっと見る</a>
# </div>
# <p class="data_source pb-2">歌ネットのアクセス数を元に作成<br/>サムネイルはAmazonのデータを参照</p>
# </div>
# </div>
# <!-- PCフローティングエリア --> <div id="pc-side-floating">
# <div class="row pc-right-column-block ms-lg-1 ms-x2 ad-area-b" id="kashi-size-banner-float">
# <div class="col-12 p-0">
# <!-- /9168657/PC_歌詞_第3レクタングル_300x250or300x600 -->
# <div id="div-gpt-ad-1626226026574-0" style="min-width: 300px; min-height: 250px;">
# <script>
#     googletag.cmd.push(function() { googletag.display('div-gpt-ad-1626226026574-0'); });
#   </script>
# </div> </div>
# </div>
# <!-- PCストリーミング記事 -->
# <div class="row pc-right-column-block ms-lg-1 ms-x2">
# <div class="side-article-box">
# <p class="ttl">STREAMING</p>
# <ol class="list p-0 m-0">
# <li class="col-12 mb-0">
# <a href="https://www.uta-net.com/streaming/linemusic/99/" onclick="dataLayer.push({ event: 'pc_analytics', eventCategory: 'song-streaming-0', eventAction: 'click', eventLabel: 'clickCount', eventValue:1 });">
# <div class="thumb">
# <img alt="" class="rounded" decoding="async" height="100" loading="lazy" src="https://www.uta-net.com/streaming/img/thumbnails/A_LINEmusic3.jpg" width="100"/>
# </div>
# <div class="title">
# 																		LINE MUSICの解約・退会方法 | できない時の対処法や注意、解約後どうなるかまで解説
# 																	</div>
# </a>
# </li>
# <li class="col-12 mb-0">
# <a href="https://www.uta-net.com/streaming/youtubemusic/123/" onclick="dataLayer.push({ event: 'pc_analytics', eventCategory: 'song-streaming-1', eventAction: 'click', eventLabel: 'clickCount', eventValue:1 });">
# <div class="thumb">
# <img alt="" class="rounded" decoding="async" height="100" loading="lazy" src="https://www.uta-net.com/streaming/img/thumbnails/A_Youtubemusic2.jpg" width="100"/>
# </div>
# <div class="title">
# 																		YouTube Musicとは？無料版と有料版の違いやトライアルの解約方法まで解説
# 																	</div>
# </a>
# </li>
# <li class="col-12 mb-0">
# <a href="https://www.uta-net.com/streaming/amazonmusic/31/" onclick="dataLayer.push({ event: 'pc_analytics', eventCategory: 'song-streaming-2', eventAction: 'click', eventLabel: 'clickCount', eventValue:1 });">
# <div class="thumb">
# <img alt="" class="rounded" decoding="async" height="100" loading="lazy" src="https://www.uta-net.com/streaming/img/thumbnails/A_amazon2.jpg" width="100"/>
# </div>
# <div class="title">
# 																		Amazon Music(アマゾンミュージック)の使い方は？無料・有料プランや機能を徹底解説
# 																	</div>
# </a>
# </li>
# <li class="col-12 mb-0">
# <a href="https://www.uta-net.com/streaming/amazonmusic/35/" onclick="dataLayer.push({ event: 'pc_analytics', eventCategory: 'song-streaming-3', eventAction: 'click', eventLabel: 'clickCount', eventValue:1 });">
# <div class="thumb">
# <img alt="" class="rounded" decoding="async" height="100" loading="lazy" src="https://www.uta-net.com/streaming/img/thumbnails/A_amazon3.jpg" width="100"/>
# </div>
# <div class="title">
# 																		Amazon Musicでの音楽のダウンロード方法。できない時の対処法や保存先の確認方法まで解説
# 																	</div>
# </a>
# </li>
# <li class="col-12 mb-0">
# <a href="https://www.uta-net.com/streaming/applemusic/10/" onclick="dataLayer.push({ event: 'pc_analytics', eventCategory: 'song-streaming-4', eventAction: 'click', eventLabel: 'clickCount', eventValue:1 });">
# <div class="thumb">
# <img alt="" class="rounded" decoding="async" height="100" loading="lazy" src="https://www.uta-net.com/streaming/img/thumbnails/A_apple3.jpg" width="100"/>
# </div>
# <div class="title">
# 																		Apple Musicファミリープランへの登録方法や友達に共有するデメリットも解説
# 																	</div>
# </a>
# </li>
# </ol>
# <div class="col-12 text-center more py-3">
# <a class="btn btn-outline-dark rounded-pill more-btn" href="https://www.uta-net.com/streaming/" onclick="dataLayer.push({ event: 'pc_analytics', eventCategory: 'song-streaming-button', eventAction: 'click', eventLabel: 'clickCount', eventValue:1 });">もっと見る</a>
# </div>
# </div>
# </div>
# <!-- /PCストリーミング記事 -->
# <!-- PCオフィシャルリンク -->
# <div class="row pc-right-column-block ms-lg-1 ms-x2 ad-area-b pc-official-link p-3">
# <h4>リンク</h4>
# <ul class="py-2 m-0">
# <li>
# <a href="http://higedan.com/" target="_blank">Official髭男dismの公式サイト</a>
# </li> <li>
# <a href="https://irorirecords.com/" target="_blank">Official髭男dismの所属レコード会社</a>
# </li> </ul>
# </div> <!-- /PCオフィシャルリンク -->
# </div>
# <!-- /PCフローティングエリア -->
# </div>
# <!-- /PC版右カラム -->
#
# <!-- Modal -->
# <div aria-hidden="true" aria-labelledby="shareModalLabel" class="modal fade" id="shareModal" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# 																	シェアする<button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button>
# </div>
# <div class="modal-body">
# <ul class="list-group list-group-flush related-sites p-0"><li class="list-group-item"><a href="https://twitter.com/share?url=https%3A%2F%2Fwww.uta-net.com%2Fsong%2F317311%2F&amp;text=Official%E9%AB%AD%E7%94%B7dism%E3%80%8C%E3%83%9F%E3%83%83%E3%82%AF%E3%82%B9%E3%83%8A%E3%83%83%E3%83%84%E3%80%8D%E3%81%AE%E6%AD%8C%E8%A9%9E%20%2F%20%E6%AD%8C%E8%A9%9E%E6%A4%9C%E7%B4%A2%E3%82%B5%E3%83%BC%E3%83%93%E3%82%B9%E3%80%8C%E6%AD%8C%E3%83%8D%E3%83%83%E3%83%88%E3%80%8D&amp;hashtags=utanet" onclick="dataLayer.push({event: 'pc_analytics', eventCategory: 'song-twitter', eventAction: 'click',eventLabel: 'TID', eventValue: 317311 });" target="_blank"><span class="icon"><img alt="Twitter" height="30" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/icon_twitter.png" width="30"/></span><span>Twitter</span></a></li><li class="list-group-item"><a href="https://www.facebook.com/share.php?u=https%3A%2F%2Fwww.uta-net.com%2Fsong%2F317311%2F" onclick="dataLayer.push({event: 'pc_analytics', eventCategory: 'song-facebook', eventAction: 'click',eventLabel: 'TID', eventValue: 317311 });" target="_blank"><span class="icon"><img alt="Facebook" height="30" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/icon_facebook.png" width="30"/></span><span>Facebook</span></a></li><li class="list-group-item"><a href="https://line.naver.jp/R/msg/text/?%E2%99%AA%20Official%E9%AB%AD%E7%94%B7dism%E3%80%8C%E3%83%9F%E3%83%83%E3%82%AF%E3%82%B9%E3%83%8A%E3%83%83%E3%83%84%E3%80%8D%E3%81%AE%E6%AD%8C%E8%A9%9E%E3%82%92%E9%80%81%E3%82%8A%E3%81%BE%E3%81%99%E2%99%AA%0Ahttps%3A%2F%2Fwww.uta-net.com%2Fsong%2F317311%2F%0A%E3%81%A9%E3%81%93%E3%82%88%E3%82%8A%E3%82%82%E6%97%A9%E3%81%84%E6%AD%8C%E8%A9%9E%E6%A4%9C%E7%B4%A2%E3%81%AF%E3%80%8C%E6%AD%8C%E3%83%8D%E3%83%83%E3%83%88%E3%80%8D%E3%81%A7%EF%BC%81%0Ahttps%3A%2F%2Fwww.uta-net.com%2F%0A" onclick="dataLayer.push({event: 'pc_analytics', eventCategory: 'song-line', eventAction: 'click',eventLabel: 'TID', eventValue: 317311 });" target="_blank"><span class="icon"><img alt="LINEで送る" height="30" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/icon_line.png" width="30"/></span><span>LINEで送る</span></a></li></ul>
# </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="buyModalLabel" class="modal fade" id="buyModal" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# 																		購入する<button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button>
# </div>
# <div class="modal-body">
# <ul class="list-group list-group-flush related-sites p-0"><li class="list-group-item reco" id="317311"><span class="icon"><img alt="レコチョク" height="28.3" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/buy_reco.png" width="85"/></span><span>レコチョク</span></li><li class="list-group-item"><a href="https://itunes.apple.com/jp/album/id1616586638?i=1616586639&amp;uo=4&amp;app=itunes&amp;at=1l3v3es" onclick="dataLayer.push({event: 'pc_analytics', eventCategory: 'song-itunesstore', eventAction: 'click',eventLabel: 'TID', eventValue: 317311 });" target="_blank"><span class="icon"><img alt="iTunes Music" height="28.3" loading="lazy" src="https://ures.jp/uta-net.com/img/sp/buy_itunes.png" width="85"/></span><span>iTunes Store</span></a></li></ul>
# </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="goodModalLabel" class="modal fade" id="goodModal" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header border-0">
# <img alt="注目度ランキング" class="m-auto" height="30" src="https://ures.jp/uta-net.com/img/pc/chumoku_title_s.gif" width="180"/>
# </div>
# <div class="modal-body">
# <p class="text-center" id="goodoresult">
# 																					「いいね！」投票ありがとうございました。
# 																				</p>
# <p class="text-center">
# <img alt="close" aria-label="Close" data-bs-dismiss="modal" height="15" src="https://ures.jp/uta-net.com/img/pc/close.gif" width="63"/>
# </p>
# </div>
# </div>
# </div>
# </div>
#
# <div class="container-fulid">
# <div class="col p-0 d-none d-lg-block" id="pc-footer">
# <div id="footer-to-top"><a class="goTop" href="#top"><span>TOP</span></a></div>
# <div id="footer-map">
# <div class="inner">
# <ul>
# <li><a href="/name_list/">アーティスト名インデックス</a></li>
# <li><a href="/anime_list/">アニソン検索・索引</a></li>
# <li><a href="/user/search_index/name.html">アルバム検索</a></li>
# <li><a href="/search/all/">歌詞全文（フレーズ）検索</a></li>
# <li><a href="/user/timemachine/index.html">タイムマシン検索</a></li>
# </ul>
# <ul>
# <li><a href="/song_info/">新曲歌詞情報</a></li>
# <li><a href="/user/newsong/release_top_2.html">新曲歌詞情報（演歌・歌謡曲）</a></li>
# <li><a href="/anime/index.html">アニメ</a></li>
# <li><a href="/streaming/">ストリーミング</a></li>
# <li><a href="/contact/">リクエストフォーム</a></li>
# </ul>
# <ul>
# <li><a href="/ranking/daily/">総合ランキング</a></li>
# <li><a href="/ranking/enka_kayo_weekly/">演歌歌謡曲ランキング</a></li>
# <li><a href="/ranking/karaoke_sogo/">カラオケランキング</a></li>
# <li><a href="/ranking/total/">歴代人気曲ランキング</a></li>
# <li><a href="/ranking/attention/">注目度ランキング</a></li>
# </ul>
# <ul>
# <li><a href="/movie/">動画プラス</a></li>
# <li><a href="/tv_program/music/">音楽番組情報</a></li>
# <li><a href="/watafure/new/">コトバのキモチ（ワタフレ）</a></li>
# <li><a href="/livereport/">ライブレポート</a></li>
# <li><a href="/today/">今日のうた</a></li>
# </ul>
# <ul>
# <li><a href="/news/">ニュース</a></li>
# <li><a href="/user/close_up/index.html">特集ピックアップ</a></li>
# <li><a href="/user/interview/index.html">インタビュー</a></li>
# <li><a href="/user/column/index.html">言葉の魔法</a></li>
# <li><a href="/user/tatsujin/index.html">言葉の達人</a></li>
# </ul>
# </div>
# </div>
# <div id="footer-bottom">
# <div id="footer-links">
# <ul>
# <li><a href="https://www.pageone.co.jp/">運営会社</a></li>
# <li><a href="https://www.pageone.co.jp/media/">メディア掲載情報</a></li>
# <li><a href="/info/kiyaku.html">利用規約</a></li>
# <li><a href="https://www.pageone.co.jp/privacy/" target="_blank">プライバシーポリシー</a></li>
# <li><a href="/contact/">お問い合わせ・リクエスト</a></li>
# <li><a href="/info/contents_info.html">コンテンツ</a></li>
# <li><a href="http://www.pageone.co.jp/ad/ad_info.html" target="_blank">広告掲載</a></li>
# <li><a href="/info/staff_index.html">スタッフ募集</a></li>
# </ul>
# </div>
# <div id="footer-text">各ページに掲載されたジャケット画像、歌詞に関する著作権は、各レコード会社、アーティストなどに帰属します。</div>
# <div id="footer-copy">
# <p class="copyright">(C)2001 PAGE ONE All Rights Reserved.</p>
# </div>
# </div>
# </div>
# <div class="col p-0 d-block d-lg-none banner-padding" id="sp-footer">
# <div>
# <a class="goTop" href="#top"><span>このページの先頭へ</span></a>
# </div>
# <div class="menu">
# <p>MENU</p>
# <ul class="row m-0">
# <li class="col-4"><a href="/">ホーム</a></li>
# <li class="col-4"><a href="/search/history.php">歌詞閲覧履歴</a></li>
# <li class="col-4"><a href="/myuta/">マイ歌ネット</a></li>
# <li class="col-4"><a href="/ranking/daily/">ランキング</a></li>
# <li class="col-4"><a href="/today/">今日のうた</a></li>
# <li class="col-4"><a href="/news/">ニュース</a></li>
# <li class="col-4"><a href="/user/pickup/index.html">ピックアップ</a></li>
# <li class="col-4"><a href="/watafure/ichiran/">コトバのキモチ</a></li>
# <li class="col-4"><a href="/user/column/index.html">言葉の魔法</a></li>
# <li class="col-4"><a href="/ranking/movie.php">動画プラス</a></li>
# <li class="col-4"><a href="/livereport/">ライブレポート</a></li>
# <li class="col-4"><a href="/user/tatsujin/index.html">言葉の達人</a></li>
# <li class="col-4"><a href="/song_info/">新曲歌詞情報</a></li>
# <li class="col-4"><a href="/streaming/">ストリーミング</a></li>
# <li class="col-4"><a href="/anime/">アニメ</a></li>
# </ul>
# </div>
# <div class="top-footer">
# <ul class="row m-0">
# <li class="col-4"><a href="https://www.pageone.co.jp/">運営会社</a></li>
# <li class="col-4"><a href="https://www.pageone.co.jp/media/">メディア掲載情報</a></li>
# <li class="col-4"><a href="/info/kiyaku.html">ご利用規約</a></li>
# <li class="col-4"><a href="/contact/">お問い合わせ</a></li>
# <li class="col-4"><a href="/static/help.php">検索ヘルプ</a></li>
# <li class="col-4"><a href="https://www.pageone.co.jp/privacy/" target="_blank">プライバシーポリシー</a></li>
# </ul>
# </div>
# <div class="copyright"><nobr>(c) 2022 Copyright. PAGE ONE All Rights Reserved.</nobr>()</div>
# </div>
# </div>
# <script src="https://ures.jp/uta-net.com/js/bootstrap/compressed/bootstrap.bundle.js"></script>
# <script src="https://ures.jp/uta-net.com/js/app.js?20220623"></script>

# %%
lyrics = utanet.get_utanet_lyrics("https://www.uta-net.com/song/317311/")
print(lyrics)
# Out:
# 袋に詰められたナッツのような世間では
# 誰もがそれぞれ出会った誰かと寄り添い合ってる
# そこに紛れ込んだ僕らはピーナッツみたいに
# 木の実のフリしながら　微笑み浮かべる
#
# 幸せのテンプレートの上　文字通り絵に描いたうわべの裏
# テーブルを囲み手を合わすその時さえ　ありのままでは居られないまま
#
# 隠し事だらけ　継ぎ接ぎだらけのHome, you know？
# 噛み砕いても無くならない　本音が歯に挟まったまま
# 不安だらけ　成り行き任せのLife, and I know
# 仮初めまみれの日常だけど　ここに僕が居て　あなたが居る
# この真実だけでもう　胃がもたれてゆく
#
# 化けの皮剥がれた一粒のピーナッツみたいに
# 世間から一瞬で弾かれてしまう　そんな時こそ
# 曲がりなりで良かったらそばに居させて
# 共に煎られ　揺られ　踏まれても　割れない殻みたいになるから
#
# 生まれた場所が木の上か地面の中か　それだけの違い
# 許されないほどにドライなこの世界を　等しく雨が湿らせますように
#
# 時に冷たくて　騒がしい窓の向こうyou know？
# 星の一つも見つからない　雷に満ちた日があっても良い
# ミスだらけ　アドリブ任せのShow, but I know
# 所詮ひとかけの日常だから　腹の中にでも　流して寝よう
#
# 隠し事だらけ　継ぎ接ぎだらけのHome, you know？
# とっておきも出来合いも　残さずに全部食らいながら
# 普通などない　正解などないLife, and I know
# 仮初めまみれの日常だけど　ここに僕が居て　あなたが居る
# この真実だけでもう　胃がもたれてゆく
# この一掴みの奇跡を　噛み締めてゆく

# %%
utanet.check_lyrics_file("Official髭男dism", "ミックスナッツ", "artists")
# Out:
# False

# %%
utanet.get_all_lyrics("ヨルシカ", "夜行")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d9fd37fe4676> in <module>
# ----> 1 utanet.get_all_lyrics("ヨルシカ", "夜行")
#
# <ipython-input-2-ca8c52195ea4> in get_all_lyrics(self, artist, folder, buffer_time)
#     116         # extract the song number on Uta-Net, song title, and artist
#     117         for entry in entries:
# --> 118             song_no = entry.find("td", class_="side td1").find("a")["href"]
#     119             song_title = entry.find("td", class_="side td1").find("a").get_text()
#     120             song_artist = entry.find("td", class_="td2").find("a").get_text()
#
# AttributeError: 'NoneType' object has no attribute 'find'
